# %%
library(Seurat)
library(magrittr)
library(harmony)
# Out:
# Loading required package: Rcpp

# %% [markdown]
# # Preprocess

# %%
data(pbmc_stim)
pbmc <- CreateSeuratObject(raw.data = cbind(stim.sparse, ctrl.sparse), project = "PBMC", min.cells = 5)
#Replace orig.ident with dataset identifiers
pbmc@meta.data$stim <- c(rep("STIM", ncol(stim.sparse)), rep("CTRL", ncol(ctrl.sparse)))

pbmc %<>% Seurat::NormalizeData()
pbmc@var.genes <- split(row.names(pbmc@meta.data), pbmc@meta.data$stim) %>% lapply(function(cells_use) {
    temp_data <- SubsetData(pbmc, cells_use)
    temp_data %<>% FindVariableGenes(do.plot = FALSE)
    head(rownames(temp_data@hvg.info), 1000)
}) %>% unlist %>% unique
pbmc %<>% ScaleData()
pbmc %<>% RunPCA(pc.genes = pbmc@var.genes, pcs.compute = 20, do.print = TRUE, pcs.print = 1:5, genes.print = 5)

# %% [markdown]
# # Perform an integrated analysis

# %%
# library(Rcpp)
# library(RcppArmadillo)
# sourceCpp("/data/srlab/ik936/harmony_weights/src/harmony.cpp")

# %%
pbmc %<>% RunHarmony("stim", theta = 2, plot_convergence = TRUE)
# Out:
# Starting harmony
# Found 2 datasets to integrate
# Using top 20 PCs
# Harmony 1/10
# WARNING: clustering did not converge after 500 iterations
# Harmony 2/10
# Clustering Converged after 205 iterations
# Harmony 3/10
# Clustering Converged after 165 iterations
# Harmony 4/10
# Clustering Converged after 115 iterations
# Harmony 5/10
# Clustering Converged after 111 iterations
# Harmony 6/10
# Clustering Converged after 259 iterations
# Harmony 7/10
# Clustering Converged after 100 iterations
# Harmony 8/10
# Clustering Converged after 137 iterations
# Harmony 9/10
# Clustering Converged after 129 iterations
# Harmony 10/10
# Clustering Converged after 78 iterations
# plot without title

# %%
options(repr.plot.height = 6, repr.plot.width = 12)
p1 <- DimPlot(object = pbmc, reduction.use = "harmony", pt.size = .1, group.by = "stim", do.return = T)
p2 <- VlnPlot(object = pbmc, features.plot = "Harmony1", group.by = "stim", do.return = TRUE)
plot_grid(p1,p2)
# Out:
# plot without title

# %%
PrintDim(object = pbmc, reduction.type = "harmony", dims.print = 1:5, genes.print = 10)
# Out:
# [1] "Harmony1"
#  [1] "C15orf48" "FCER1G"   "TYROBP"   "SOD2"     "CST3"     "TIMP1"
#  [7] "FTL"      "ANXA5"    "LGALS3"   "LGALS1"
# [1] ""
#  [1] "RPL21"  "PTMA"   "RPS6"   "RPL3"   "RPS3"   "RPL13A" "RPS18"  "RPL7"
#  [9] "RPS27A" "RPS14"
# [1] ""
# [1] ""
# [1] "Harmony2"
#  [1] "CCR7"   "PABPC1" "LTB"    "SELL"   "RPS12"  "RPS13"  "RPS23"  "RPL32"
#  [9] "RPLP2"  "RPL18A"
# [1] ""
#  [1] "NKG7"     "GNLY"     "GZMB"     "CCL5"     "CST7"     "PRF1"
#  [7] "APOBEC3G" "CLIC3"    "KLRD1"    "GZMH"
# [1] ""
# [1] ""
# [1] "Harmony3"
#  [1] "S100A8" "S100A9" "IL8"    "CD63"   "FCER1G" "TYROBP" "CD14"   "LGALS1"
#  [9] "LYZ"    "CLEC5A"
# [1] ""
#  [1] "CCR7"   "RPL18A" "RPS27"  "RPS5"   "RPS19"  "RPS6"   "PTMA"   "LTB"
#  [9] "RPL13A" "CD79A"
# [1] ""
# [1] ""
# [1] "Harmony4"
#  [1] "CD3D"   "GIMAP7" "GIMAP5" "LDHB"   "GIMAP4" "RPL34"  "HBA1"   "LTB"
#  [9] "CD3E"   "PABPC1"
# [1] ""
#  [1] "HLA-DQA1" "CD83"     "CD74"     "HLA-DQB1" "HLA-DPA1" "HLA-DRB1"
#  [7] "HLA-DRA"  "HLA-DPB1" "HSP90AB1" "HERPUD1"
# [1] ""
# [1] ""
# [1] "Harmony5"
#  [1] "CACYBP"      "DNAJB1"      "ANXA1"       "H3F3B"       "HSPH1"
#  [6] "GIMAP7"      "ZFAND2A"     "RP11-51J9.5" "SRSF2"       "DDIT4"
# [1] ""
#  [1] "CD79A"    "MS4A1"    "CD74"     "HLA-DRA"  "HLA-DPB1" "HLA-DRB1"
#  [7] "HLA-DPA1" "HLA-DQB1" "HLA-DQA1" "IRF8"
# [1] ""
# [1] ""

# %%
DimHeatmap(object = pbmc, reduction.type = "harmony", cells.use = 500, dim.use = 1:6, do.balanced = TRUE)
# Out:
# Plot with title “Harmony 6”

# %% [markdown]
# # Seurat tSNE Functions for Integrated Analysis Using Harmony Results
#
# Similar to the linked vigenette, the harmony results can be used for integrated analysis. You simply replace the CCA dimensional reduction with Harmony.

# %%
system.time({
pbmc %<>% RunTSNE(reduction.use = "harmony", dims.use = 1:20, do.fast = T)
pbmc %<>% FindClusters(reduction.type = "harmony", resolution = 0.6, dims.use = 1:20, force.recalc = TRUE, print.output = FALSE)
})
# Out:
#    user  system elapsed
# 315.633   0.002 316.004

# %%
p3 <- TSNEPlot(pbmc, do.return = T, pt.size = 0.5, group.by = "stim")
p4 <- TSNEPlot(pbmc, do.label = T, do.return = T, pt.size = 0.5)
plot_grid(p3, p4)
# Out:
# plot without title

# %% [markdown]
# # Identify conserved cell type markers

# %%
# markers <- pbmc %>% SetAllIdent("res.0.6") %>% FindConservedMarkers()
nk.markers <- FindConservedMarkers(pbmc, ident.1 = 5, grouping.var = "stim", print.bar = FALSE)
head(nk.markers)
# Out:
# Warning message in if (!ident.use.2 %in% object@ident) {:
# “the condition has length > 1 and only the first element will be used”

# %%
options(repr.plot.height = 10, repr.plot.width = 12)
FeaturePlot(object = pbmc, features.plot = c("CD3D", "SELL", "CREM", "CD8A", "GNLY", "CD79A", "FCGR3A", "CCL2", "PPBP"), 
            min.cutoff = "q9", cols.use = c("lightgrey", "blue"), pt.size = 0.5)
# Out:
# plot without title

# %%
pbmc %<>% SetAllIdent("res.0.6")

new.ident <- c("CD4 Naive T", "CD4 Memory T", "CD14 Mono1", "CD14 Mono2", "B", "NK", "CD8 T", 
  "T activated", "CD16 Mono", "Mk", "B activated", "Eryth", "DC", "pDC")
for (i in 1:length(new.ident)) {
    pbmc %<>% RenameIdent(old.ident.name = i - 1, new.ident.name = new.ident[i])
}

TSNEPlot(pbmc, do.label = T, pt.size = 0.5)
# Out:
# plot without title

# %%
options(repr.plot.height = 8, repr.plot.width = 12)
pbmc@ident <- factor(pbmc@ident, levels = (c("pDC", "Eryth", 
    "Mk", "DC", "CD14 Mono1", "CD14 Mono2", "CD16 Mono", "B activated", "B", "CD8 T", "NK", 
    "T activated", "CD4 Naive T", "CD4 Memory T")))
markers.to.plot <- c("CD3D", "CREM", "HSPH1", "SELL", "GIMAP5", "CACYBP", "GNLY", 
    "NKG7", "CCL5", "CD8A", "MS4A1", "CD79A", "MIR155HG", "NME1", "FCGR3A", 
    "VMO1", "CCL2", "S100A9", "HLA-DQA1", "GPR183", "PPBP", "GNG11", "HBA2", 
    "HBB", "TSPAN13", "IL3RA", "IGJ")
sdp <- SplitDotPlotGG(pbmc, genes.plot = rev(markers.to.plot), cols.use = c("blue", "red"), 
                      x.lab.rot = T, plot.legend = T, dot.scale = 8, do.return = T, grouping.var = "stim")
# Out:
# plot without title
